# %% [markdown]
# # Deck of Cards
#
# https://isaac-flath.github.io/deck_of_cards/
#
# > A minimal example of using nbprocess to create a python library.

# %% [markdown]
# This repo uses code from [Allen Downey's](http://allendowney.com/) [ThinkPython2](https://github.com/AllenDowney/ThinkPython2). _This file was automatically generated from a Jupyter Notebook using [nbprocess](https://nbprocess.fast.ai/). to change it you must edit [index.ipynb](https://github.com/isaac-flath/deck_of_cards/blob/master/index.ipynb)._

# %% [markdown]
# ## Install

# %% [markdown]
# After cloning this repository:

# %% [markdown]
# `pip install -e .`

# %% [markdown]
# > There is already a project called [deck_of_cards on pypi](https://pypi.org/project/deck-of-cards/). This project has no relation to that. This project is an example of how to create python packages with [nbprocess](https://github.com/fastai/nbprocess).

# %% [markdown]
# ## How to use

# %% [markdown]
# Playing cards in python!

# %%
from deck_of_cards.deck import Deck
d = Deck()
print(f'Number of playing cards in the deck: {len(d.cards)}')
# Out:
# Number of playing cards in the deck: 52

# %%
card = d.pop_card()
print(card)
# Out:
# King of Spades

# %% [markdown]
# See [the docs](https://isaac-flath.github.io/deck_of_cards/) for more info.
